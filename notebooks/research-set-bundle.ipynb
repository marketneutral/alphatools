# %%
from alphatools.research import (
    get_pricing,
    set_bundle
)
# Out:
# /Users/jonathan/.zipline/extension.py:15: UserWarning: Overwriting bundle with name 'csvdir'
#   end_session=end_session

# %%
df = get_pricing(['AAPL', 'MSFT'], '2001-01-04', '2017-12-29')

# %%
df.plot();

# %%
set_bundle('csvdir')

# %%
df = get_pricing(['US1'], '2001-01-04', '2017-12-29')

# %%
df.plot()
